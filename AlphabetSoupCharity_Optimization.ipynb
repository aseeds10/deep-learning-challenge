# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
## Preprocessing

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=["EIN", "NAME"], inplace=True)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
applic_type_value_counts = application_df["APPLICATION_TYPE"].value_counts()
applic_type_value_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# CHANGE CUT-OFF POINT FOR OTHER APPLIC TYPE
#empty list to set up conditional to fill with applic types that pass threshold
application_types_to_replace = []

# Iterate over the counts
for each, count in applic_type_value_counts.items():
    if count < 700:
        application_types_to_replace.append(each)

# print(application_types_to_replace)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_value_counts = application_df["CLASSIFICATION"].value_counts()

for classification, count in classification_value_counts.items():
    if count > 1:
        print(f"{classification}: {count}")
# Out:
# C1000: 17326
# C2000: 6074
# C1200: 4837
# C3000: 1918
# C2100: 1883
# C7000: 777
# C1700: 287
# C4000: 194
# C5000: 116
# C1270: 114
# C2700: 104
# C2800: 95
# C7100: 75
# C1300: 58
# C1280: 50
# C1230: 36
# C1400: 34
# C7200: 32
# C2300: 32
# C1240: 30
# C8000: 20
# C7120: 18
# C1500: 16
# C1800: 15
# C6000: 15
# C1250: 14
# C8200: 11
# C1238: 10
# C1278: 10
# C1235: 9
# C1237: 9
# C7210: 7
# C2400: 6
# C1720: 6
# C4100: 6
# C1257: 5
# C1600: 5
# C1260: 3
# C2710: 3
# C0: 3
# C3200: 2
# C1234: 2
# C1246: 2
# C1267: 2
# C1256: 2

# %%
#KEEP SAME CUT-OFF FOR CLASSIFICATION
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = []

# Iterate over the counts
for classification, count in classification_value_counts.items():
    if count < 1000:
        classifications_to_replace.append(classification)

print(classifications_to_replace)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# ['C7000', 'C1700', 'C4000', 'C5000', 'C1270', 'C2700', 'C2800', 'C7100', 'C1300', 'C1280', 'C1230', 'C1400', 'C7200', 'C2300', 'C1240', 'C8000', 'C7120', 'C1500', 'C1800', 'C6000', 'C1250', 'C8200', 'C1238', 'C1278', 'C1235', 'C1237', 'C7210', 'C2400', 'C1720', 'C4100', 'C1257', 'C1600', 'C1260', 'C2710', 'C0', 'C3200', 'C1234', 'C1246', 'C1267', 'C1256', 'C2190', 'C4200', 'C2600', 'C5200', 'C1370', 'C1248', 'C6100', 'C1820', 'C1900', 'C1236', 'C3700', 'C2570', 'C1580', 'C1245', 'C2500', 'C1570', 'C1283', 'C2380', 'C1732', 'C1728', 'C2170', 'C4120', 'C8210', 'C2561', 'C4500', 'C2150']
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
#check counts of SPECIAL_CONSIDERATIONS to see if noisy data
application_df["SPECIAL_CONSIDERATIONS"].value_counts()
#NOTE: vast majority are N so will drop to quiet noise in model
# Out:
# SPECIAL_CONSIDERATIONS
# N    34272
# Y       27
# Name: count, dtype: int64

# %%
#check counts of STATUS to see if noisy data
application_df["STATUS"].value_counts()
#NOTE: vast majority are 1 so will drop to quiet noise in model
# Out:
# STATUS
# 1    34294
# 0        5
# Name: count, dtype: int64

# %%
# Drop the non-beneficial columns, 'SPECIAL_CONSIDERATIONS' and 'STATUS'.
application_df.drop(columns=["SPECIAL_CONSIDERATIONS", "STATUS"], inplace=True)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0            Other       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION     INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0   Association              0     5000              1
# 1  Co-operative         1-9999   108590              1
# 2   Association              0     5000              0
# 3         Trust    10000-24999     6692              1
# 4         Trust  100000-499999   142590              1

# %%
#check ask_amt min, max, mean/median?
application_df['ASK_AMT'].describe()
# Out:
# count    3.429900e+04
# mean     2.769199e+06
# std      8.713045e+07
# min      5.000000e+03
# 25%      5.000000e+03
# 50%      5.000000e+03
# 75%      7.742000e+03
# max      8.597806e+09
# Name: ASK_AMT, dtype: float64

# %%
# # categorize ask amount to reduce noise in model

# # Define the bins and labels
# # bins = [0, 10000, 100000, 1000000, 10000000, 100000000, 1000000000, 9000000000]
# bins = [0, 10000, 100000, 1000000, 9000000000]
# labels = ['0-9,999', '10,000-99,999', '100,000-999,999', '1,000,000 or more']

# # Bin the 'ASK_AMT' column
# application_df['ASK_AMT'] = pd.cut(application_df['ASK_AMT'], bins=bins, labels=labels, include_lowest=True)

# # Display the DataFrame
# application_df.head()

# %%
# application_df['ASK_AMT'].value_counts()

# %%
# Convert categorical data to numeric with `pd.get_dummies`
# application_df_copy =  application_df.copy()
# application_dummies = pd.get_dummies(application_df, \
#                                      columns=['APPLICATION_TYPE', \
#                                               'CLASSIFICATION', 'AFFILIATION', \
#                                               'USE_CASE', 'ORGANIZATION', \
#                                               'INCOME_AMT', 'ASK_AMT'], \
#                                      drop_first=True)

application_dummies = pd.get_dummies(application_df, \
                                     columns=['APPLICATION_TYPE', \
                                              'CLASSIFICATION', 'AFFILIATION', \
                                              'USE_CASE', 'ORGANIZATION', \
                                              'INCOME_AMT'], \
                                     drop_first=True)

application_dummies.head()
# Out:
#    ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0     5000              1                 False                False
# 1   108590              1                 False                 True
# 2     5000              0                 False                False
# 3     6692              1                 False                 True
# 4   142590              1                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  \
# 0                False                False                False
# 1                False                False                False
# 2                False                 True                False
# 3                False                False                False
# 4                False                False                False
#
#    APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  CLASSIFICATION_C1200  ...  \
# 0                False                False                 False  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = application_dummies["IS_SUCCESSFUL"]
X = application_dummies.drop(["IS_SUCCESSFUL"], axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train_scaled[:1]
# Out:
# array([[-0.03348439, -0.1803104 , -1.93323172, -0.21721176, -0.18886807,
#          5.27316518, -0.14490076, -0.14712247, -0.4053369 ,  2.1506258 ,
#         -0.24198608, -0.24360198, -0.26416456, -0.04500615, -1.07924659,
#         -0.03180805, -0.00623504, -0.01972038, -0.06215637, -0.00881785,
#         -2.13840836,  2.25801349, -0.11744636, -0.033595  ,  0.67506919,
#         -0.14849557, -0.12694995, -0.32918556, -0.08347349, -0.16981325,
#         -0.35186578, -0.06401969, -0.06987849]])

# %%
## Compile, Train and Evaluate the Model

# %%
print(len(X_train.columns))
# Out:
# 33

# %%
# MODEL 1
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train.columns)
hidden_nodes_layer1 =  10
hidden_nodes_layer2 = 5

nn = tf.keras.models.Sequential()

# Input layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="tanh")
)

# 1st hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 10)                  │             340 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │              55 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6695 - loss: 0.6256
# Epoch 2/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7323 - loss: 0.5608
# Epoch 3/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7268 - loss: 0.5620
# Epoch 4/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7311 - loss: 0.5522
# Epoch 5/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7283 - loss: 0.5562
# Epoch 6/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7306 - loss: 0.5541
# Epoch 7/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7325 - loss: 0.5500
# Epoch 8/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7353 - loss: 0.5477
# Epoch 9/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7334 - loss: 0.5500
# Epoch 10/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7323 - loss: 0.5494
# Epoch 11/100
# ...

# %%
# Evaluate the model using the test data - MODEL 1
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - 1ms/step - accuracy: 0.7266 - loss: 0.5527
# Loss: 0.5527328848838806, Accuracy: 0.7266472578048706

# %%
# MODEL 2
# Define the model
nodes_layer1 =  15
nodes_layer2 = 5

nn2 = tf.keras.models.Sequential()

# Input layer
nn2.add(
    tf.keras.layers.Dense(units=nodes_layer1, input_dim=number_input_features, activation="tanh")
)

# 1st hidden layer
nn2.add(tf.keras.layers.Dense(units=nodes_layer2, activation="tanh"))

# Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 15)                  │             510 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 5)                   │              80 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               6 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 596 (2.33 KB)
#  Trainable params: 596 (2.33 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model - model 2
nn2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model - model 2
fit_model2 = nn2.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6807 - loss: 0.6134
# Epoch 2/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7308 - loss: 0.5598
# Epoch 3/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7363 - loss: 0.5504
# Epoch 4/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7299 - loss: 0.5557
# Epoch 5/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7264 - loss: 0.5543
# Epoch 6/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7335 - loss: 0.5519
# Epoch 7/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7314 - loss: 0.5535
# Epoch 8/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7339 - loss: 0.5509
# Epoch 9/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7333 - loss: 0.5495
# Epoch 10/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7328 - loss: 0.5486
# Epoch 11/100
# ...

# %%
# Evaluate the model using the test data - model 2
model_loss2, model_accuracy2 = nn2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss2}, Accuracy: {model_accuracy2}")
# Out:
# 268/268 - 0s - 1ms/step - accuracy: 0.7251 - loss: 0.5520
# Loss: 0.551978349685669, Accuracy: 0.7251312136650085

# %%
# MODEL 3
# Define the model
nodes_layer3 =  10
nodes_layer4 = 5
nodes_layer5 = 3

nn3 = tf.keras.models.Sequential()

# Input layer
nn3.add(
    tf.keras.layers.Dense(units=nodes_layer3, input_dim=number_input_features, activation="tanh")
)

# 1st hidden layer
nn3.add(tf.keras.layers.Dense(units=nodes_layer4, activation="tanh"))

# # 2nd hidden layer
nn3.add(tf.keras.layers.Dense(units=nodes_layer5, activation="tanh"))

# Output layer
nn3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 10)                  │             340 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 5)                   │              55 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 3)                   │              18 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 1)                   │               4 │
# ...

# %%
# Compile the model - model 3
nn3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model - model 3
fit_model3 = nn3.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6777 - loss: 0.6168
# Epoch 2/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7285 - loss: 0.5664
# Epoch 3/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7320 - loss: 0.5580
# Epoch 4/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7316 - loss: 0.5586
# Epoch 5/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7273 - loss: 0.5588
# Epoch 6/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7294 - loss: 0.5543
# Epoch 7/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7317 - loss: 0.5533
# Epoch 8/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7311 - loss: 0.5530
# Epoch 9/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7291 - loss: 0.5548
# Epoch 10/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7391 - loss: 0.5465
# Epoch 11/100
# ...

# %%
# Evaluate the model using the test data - model 3
model_loss3, model_accuracy3 = nn3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss3}, Accuracy: {model_accuracy3}")
# Out:
# 268/268 - 0s - 1ms/step - accuracy: 0.7231 - loss: 0.5553
# Loss: 0.5552785992622375, Accuracy: 0.7231487035751343

# %%
# MODEL 4
# Define the model
hidden_nodes_layer6 =  15
# hidden_nodes_layer7 = 5

nn4 = tf.keras.models.Sequential()

# Input layer
nn4.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer6, input_dim=number_input_features, activation="tanh")
)

# # 1st hidden layer
# nn4.add(tf.keras.layers.Dense(units=hidden_nodes_layer7, activation="tanh"))

# Output layer
nn4.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn4.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                     │ (None, 15)                  │             510 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 1)                   │              16 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 526 (2.05 KB)
#  Trainable params: 526 (2.05 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model - model 4
nn4.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model - model 4
fit_model4 = nn4.fit(X_train_scaled,y_train,epochs=200)
# Out:
# Epoch 1/200
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7422 - loss: 0.5391
# Epoch 2/200
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7357 - loss: 0.5431
# Epoch 3/200
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7438 - loss: 0.5335
# Epoch 4/200
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7389 - loss: 0.5392
# Epoch 5/200
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7336 - loss: 0.5444
# Epoch 6/200
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7377 - loss: 0.5384
# Epoch 7/200
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7391 - loss: 0.5389
# Epoch 8/200
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7386 - loss: 0.5379
# Epoch 9/200
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7403 - loss: 0.5377
# Epoch 10/200
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7396 - loss: 0.5377
# Epoch 11/200
# ...

# %%
# Evaluate the model using the test data - model 4
model_loss4, model_accuracy4 = nn4.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss4}, Accuracy: {model_accuracy4}")
# Out:
# 268/268 - 0s - 797us/step - accuracy: 0.7252 - loss: 0.5533
# Loss: 0.553287148475647, Accuracy: 0.7252478003501892

# %%
# MODEL 5
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nodes_layer8 =  10
nodes_layer9 = 5

nn5 = tf.keras.models.Sequential()

# Input layer
nn5.add(
    tf.keras.layers.Dense(units=nodes_layer8, input_dim=number_input_features, activation="tanh")
)

# 1st hidden layer
nn5.add(tf.keras.layers.Dense(units=nodes_layer9, activation="tanh"))

# Output layer
nn5.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn5.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                     │ (None, 10)                  │             340 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 5)                   │              55 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
# Compile the model - model 5
nn5.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model - model 5
fit_model5 = nn5.fit(X_train_scaled,y_train,epochs=20)
# Out:
# Epoch 1/20
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7402 - loss: 0.5413
# Epoch 2/20
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7358 - loss: 0.5446
# Epoch 3/20
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7429 - loss: 0.5373
# Epoch 4/20
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7370 - loss: 0.5408
# Epoch 5/20
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7378 - loss: 0.5405
# Epoch 6/20
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7384 - loss: 0.5436
# Epoch 7/20
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7411 - loss: 0.5391
# Epoch 8/20
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7371 - loss: 0.5402
# Epoch 9/20
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7409 - loss: 0.5389
# Epoch 10/20
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7383 - loss: 0.5422
# Epoch 11/20
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7411 - loss: 0.5362
# ...

# %%
# Evaluate the model using the test data - model 5
model_loss5, model_accuracy5 = nn5.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss5}, Accuracy: {model_accuracy5}")
# Out:
# 268/268 - 0s - 942us/step - accuracy: 0.7268 - loss: 0.5548
# Loss: 0.5547882318496704, Accuracy: 0.7267638444900513

# %%
# MODEL 6
# Define the model - like 5 but more neurons
nodes_layer10 =  28
nodes_layer11 = 5

nn6 = tf.keras.models.Sequential()

# Input layer
nn6.add(
    tf.keras.layers.Dense(units=nodes_layer10, input_dim=number_input_features, activation="tanh")
)

# 1st hidden layer
nn6.add(tf.keras.layers.Dense(units=nodes_layer11, activation="tanh"))

# Output layer
nn6.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn6.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_23 (Dense)                     │ (None, 28)                  │             952 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_24 (Dense)                     │ (None, 5)                   │             145 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 1)                   │               6 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,103 (4.31 KB)
#  Trainable params: 1,103 (4.31 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model - model 6
nn6.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model - model 6
fit_model6 = nn6.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7389 - loss: 0.5383
# Epoch 2/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7389 - loss: 0.5398
# Epoch 3/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7417 - loss: 0.5408
# Epoch 4/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7438 - loss: 0.5340
# Epoch 5/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7435 - loss: 0.5341
# Epoch 6/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7370 - loss: 0.5405
# Epoch 7/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7379 - loss: 0.5369
# Epoch 8/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7366 - loss: 0.5422
# Epoch 9/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7404 - loss: 0.5347
# Epoch 10/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7387 - loss: 0.5399
# Epoch 11/100
# ...

# %%
# Evaluate the model using the test data - model 6
model_loss6, model_accuracy6 = nn6.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss6}, Accuracy: {model_accuracy6}")
# Out:
# 268/268 - 0s - 913us/step - accuracy: 0.7266 - loss: 0.5525
# Loss: 0.5524623394012451, Accuracy: 0.7266472578048706

# %%
# Export chosen model to HDF5 file
nn5.save("AlphabetSoupCharity_Optimization.h5")
from google.colab import files
files.download("AlphabetSoupCharity_Optimization.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
